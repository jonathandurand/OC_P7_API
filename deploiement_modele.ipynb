# %%
pip install -q dagshub mlflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 64.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.7/733.7 kB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.4/118.4 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 4.4 MB/s eta 0:00:00

# %%
import mlflow

# %%
import dagshub
dagshub.auth.add_app_token('7ff59a8ec595a39c81790087b5fe632c13a71e8c')
dagshub.init(repo_owner='jonathan.durand25', repo_name='OC_P7', mlflow=True)
# Out:
# Accessing as jonathan.durand25
# Initialized MLflow to track repo "jonathan.durand25/OC_P7"
# Repository jonathan.durand25/OC_P7 initialized!

# %%
# !pip install awscli
# !pip install boto3
# Out:
# Collecting awscli
#   Downloading awscli-1.40.31-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: botocore==1.38.32 in /usr/local/lib/python3.11/dist-packages (from awscli) (1.38.32)
# Collecting docutils<=0.19,>=0.18.1 (from awscli)
#   Downloading docutils-0.19-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from awscli) (0.13.0)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /usr/local/lib/python3.11/dist-packages (from awscli) (6.0.2)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from botocore==1.38.32->awscli) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore==1.38.32->awscli) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore==1.38.32->awscli) (2.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.38.32->awscli) (1.17.0)
# Downloading awscli-1.40.31-py3-none-any.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 60.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading docutils-0.19-py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 32.6 MB/s eta 0:00:00
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Installing collected packages: rsa, docutils, colorama, awscli
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9.1
#     Uninstalling rsa-4.9.1:
#       Successfully uninstalled rsa-4.9.1
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.21.2
#     Uninstalling docutils-0.21.2:
#       Successfully uninstalled docutils-0.21.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.19 which is incompatible.
# Successfully installed awscli-1.40.31 colorama-0.4.6 docutils-0.19 rsa-4.7.2
# Requirement already satisfied: boto3 in /usr/local/lib/python3.11/dist-packages (1.38.32)
# Requirement already satisfied: botocore<1.39.0,>=1.38.32 in /usr/local/lib/python3.11/dist-packages (from boto3) (1.38.32)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from boto3) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.32->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.32->boto3) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.32->boto3) (1.17.0)

# %%
# !aws configure set default.region us-east-1
# !aws configure set aws_access_key_id AKIAWBGQKJ5PPNMBEJUF
# !aws configure set aws_secret_access_key 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

# %%
mlflow.get_tracking_uri()
# Out:
# 'https://dagshub.com/jonathan.durand25/OC_P7.mlflow'

# %%
from mlflow.deployments import get_deploy_client

region = 'us-east-1'
# You can run "aws sts get-caller-identity" to get your AWS ID
aws_id = '414901227358'
# Use ARN from the role we created in AWS with the full permission to Sagemaker
arn = 'arn:aws:iam::414901227358:role/Sagemaker_OC'
#Create your name of the future application
app_name = 'test_OC'
# you may find model uri in "mlflow ui" recorded as "logged_model"
model_uri = f'runs:/6d80e252e0bd4b05a603a85611298913/baseline-model'
# tag_id is equal to the mlflow version. It is used in Docker url
tag_id = '2.22.0'


image_url = '414901227358.dkr.ecr.us-east-1.amazonaws.com/mlflow-pyfunc:2.22.0'


config = dict(
    execution_role_arn=arn,
    bucket_name="New-s3-bucket",
    image_url=image_url,
    region_name=region,
    archive=False,
    instance_type="ml.t2.medium",
    instance_count=1,
    synchronous=True,
    timeout_seconds=3600,
    variant_name="prod-variant-1",
    tags={"training_timestamp": "2023-08-31"}
)

client = get_deploy_client("sagemaker")

client.create_deployment(
    #you can use any name you want to see in Sagemaker"
    "my-deployment-attemp",
    model_uri=model_uri,
    flavor="python_function",
    config=config,
)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025/06/07 13:36:43 INFO mlflow.sagemaker: Using the python_function flavor for deployment!
# 2025/06/07 13:36:44 INFO mlflow.sagemaker: No model data bucket specified, using the default bucket
# 2025/06/07 13:36:45 INFO mlflow.sagemaker: Default bucket `mlflow-sagemaker-us-east-1-414901227358` already exists. Skipping creation.
# 2025/06/07 13:36:46 INFO mlflow.sagemaker: tag response: {'ResponseMetadata': {'RequestId': '9B7DNG3GHSC4W4AS', 'HostId': '5t6M5V3tXQdZAmT1pIPEAZFWTfBKVsKvtYJgpSNTNEWKxFzbFVXfhavsIlOHcqqDC7JrMc36fwA=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '5t6M5V3tXQdZAmT1pIPEAZFWTfBKVsKvtYJgpSNTNEWKxFzbFVXfhavsIlOHcqqDC7JrMc36fwA=', 'x-amz-request-id': '9B7DNG3GHSC4W4AS', 'date': 'Sat, 07 Jun 2025 13:36:47 GMT', 'content-length': '0', 'server': 'AmazonS3'}, 'RetryAttempts': 0}}
# 2025/06/07 13:36:46 INFO mlflow.sagemaker: Creating new endpoint with name: my-deployment-attemp ...
# 2025/06/07 13:36:47 INFO mlflow.sagemaker: Created model with arn: arn:aws:sagemaker:us-east-1:414901227358:model/my-deployment-attemp-model-3108018659824a1a9b3b
# 2025/06/07 13:36:48 INFO mlflow.sagemaker: Created endpoint configuration with arn: arn:aws:sagemaker:us-east-1:414901227358:endpoint-config/my-deployment-attemp-config-2d57418c697b447aa45a
# 2025/06/07 13:36:48 INFO mlflow.sagemaker: Created endpoint with arn: arn:aws:sagemaker:us-east-1:414901227358:endpoint/my-deployment-attemp
# 2025/06/07 13:36:48 INFO mlflow.sagemaker: Waiting for the deployment operation to complete...
# 2025/06/07 13:36:49 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:37:09 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:37:30 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:37:50 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:38:11 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:38:31 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:38:52 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:39:12 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:39:33 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:39:53 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:40:14 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:40:34 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:40:55 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:41:16 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:41:36 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:41:57 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:42:17 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:42:38 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:42:59 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:43:19 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:43:40 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:44:00 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:44:21 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:44:42 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:45:02 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:45:23 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:45:43 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:46:04 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:46:24 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:46:45 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:47:05 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:47:26 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:47:46 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:48:07 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:48:27 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:48:48 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:49:09 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:49:29 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:49:50 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:50:10 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:50:31 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:50:51 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:51:12 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:51:32 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:51:53 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:52:13 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:52:34 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:52:55 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:53:15 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:53:36 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:53:56 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:54:17 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:54:37 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:54:58 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:55:19 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:55:39 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:56:00 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:56:20 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:56:41 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:57:02 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:57:22 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:57:43 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:58:03 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:58:24 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:58:44 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:59:05 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:59:25 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 13:59:46 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 14:00:06 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 14:00:27 INFO mlflow.sagemaker: Waiting for endpoint to reach the "InService" state. Current endpoint status: "Creating"
# 2025/06/07 14:00:32 INFO mlflow.sagemaker: The deployment operation completed successfully with message: "The SageMaker endpoint was created successfully."
# {'name': 'my-deployment-attemp', 'flavor': 'python_function'}
