# %%
pip install -q dagshub mlflow
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import mlflow

# %%
import dagshub
dagshub.auth.add_app_token('7ff59a8ec595a39c81790087b5fe632c13a71e8c')
dagshub.init(repo_owner='jonathan.durand25', repo_name='OC_P7', mlflow=True)
# Out:
# The added token already exists in the token cache, skipping
# Accessing as jonathan.durand25
# Initialized MLflow to track repo "jonathan.durand25/OC_P7"
# Repository jonathan.durand25/OC_P7 initialized!

# %%
mlflow.get_tracking_uri()
# Out:
# 'https://dagshub.com/jonathan.durand25/OC_P7.mlflow'

# %%
# !mlflow models build-docker --model-uri "runs:/6d80e252e0bd4b05a603a85611298913/baseline-model" --name "my-image-name"
# Out:
# ...
# 2025/06/07 12:15:00 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
#
# ...
# 2025/06/07 12:15:04 INFO mlflow.pyfunc.backend: Building docker image with name my-image-name
# D:\logiciels\Anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# D:\logiciels\Anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# D:\logiciels\Anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
# ...
